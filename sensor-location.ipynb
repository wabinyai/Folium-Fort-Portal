# %% [markdown]
# #  Mapping airqo devices in Fort Portal city  in Python using Folium

# %% [markdown]
# Engineering projects that involve data visualization occasionally include a geographic component.
#
#  Folium is a package that provides interactive Python map visualizations by running the JavaScript leaflet.js module in the background.

# %% [markdown]
# To familiarize ourselves, use the folium library to map AirQo sensors in Fort Portal City in a way that is easy for the user.

# %% [markdown]
# ## Installing folium
# Let's start by by installing folium. In Google Colab and Kaggle kernels, folium comes preinstalled.
# If you are not using the aforementioned IDE, then install using the following commands.

# %%
#pip install folium
#or 
#conda install -c conda-forge folium

# %% [markdown]
# # Library

# %% [markdown]
# Import the necessary libraries to be used in the project

# %%
import folium
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seabon as sn

# %% [markdown]
# After importing the necessary libraries, read the dataset using pandas.

# %% [markdown]
# # Data frame

# %%
fort = pd.read_csv('D:\PYTHON\WORK-2022\spatial-model/fort_portal/sensor-loc-fort.csv')
#view the dataset
fort.head()
# Out:
#    Unnamed: 0      name       id       lat      long  \
# 0           0  aq_g5_36  1429567  0.688800  30.26955
# 1           1   aq_g533  1379966  0.647260  30.26844
# 2           2   aq_g530  1375499  0.656900  30.27896
# 3           3   aq_g528  1375496  0.655610  30.27199
# 4           4     aq_10   676000  0.657624  30.26763
#
#                     location
# 0       Kiteere,Kibimba Ward
# 1   Toro Palace, Bazaar Ward
# 2  Mpanga Market, Njara Ward
# 3        Lory Park, Rwengoma
# 4                   Rwengoma

# %% [markdown]
# ## Plotting Maps with Folium
#
# Plotting using folium is quite easy. The folium.Map()  class takes in latitude and longitude coordinates to generate an interactive map. You can use the + and - button on the map to zoom in and out.
#
#  The hand icon is used to drag the map to any location. Folium allows one to set a start zoom, maximum and minimum zoom number.

# %%
map_fort=folium.Map( location=[0.66,30.27],zoom_start=13,min_zoom=8,max_zoom=14)
map_fort
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12114af382551b92cdcb141b4a098634 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12114af382551b92cdcb141b4a098634&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_12114af382551b92cdcb141b4a098634 = L.map(
#                 &quot;map_12114af382551b92cdcb141b4a098634&quot;,
#                 {
#                     center: [0.66, 30.27],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3d54f15c50df8474cb85a61ad5a2afcc = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 14, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_12114af382551b92cdcb141b4a098634);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # To center the map

# %% [markdown]
# To easily center the map, use the mean latitude and longitude of where the devices are stationed.

# %%
long =fort['long'].mean()
lat = fort['lat'].mean()

# %%
long
# Out:
# 30.268724444444445

# %%
lat
# Out:
# 0.6571148888888888

# %%
map_fort=folium.Map( location=[lat,long],zoom_start=13,min_zoom=8,max_zoom=14)
map_fort
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_24ecd40ff0f6d8f06b6f92d27e67ef33 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_24ecd40ff0f6d8f06b6f92d27e67ef33&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_24ecd40ff0f6d8f06b6f92d27e67ef33 = L.map(
#                 &quot;map_24ecd40ff0f6d8f06b6f92d27e67ef33&quot;,
#                 {
#                     center: [0.6571148888888888, 30.268724444444445],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_abf489665c6020b434f1270ff861f7df = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 14, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_24ecd40ff0f6d8f06b6f92d27e67ef33);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #  Plotting Markers on the Map
#
# Markers are used to mark the locations. To add markers on the map use folium uses folium.Marker() class.
#  The latitude and longitude is picked from csv file.
# folium.Icon() class is used to create icons for the markers.

# %%
map_fort=folium.Map( location=[lat,long],zoom_start=13,min_zoom=8,max_zoom=14)


 
for index, row in fort.iterrows():
    label = f'{row["location"]}'
    folium.Marker(location=[row['lat'], row['long']], 
                      popup=folium.Popup(html=label, show=False, sticky=True), 
                      icon=folium.Icon(color='red'),
                      tooltip=label).add_to(map_fort)
map_fort.save('D:\PYTHON\WORK-2022\spatial-model/fort_portal/map_fort.html')
map_fort
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_21fe0eecbd50f0438c43a7ca3da69cf8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_21fe0eecbd50f0438c43a7ca3da69cf8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_21fe0eecbd50f0438c43a7ca3da69cf8 = L.map(
#                 &quot;map_21fe0eecbd50f0438c43a7ca3da69cf8&quot;,
#                 {
#                     center: [0.6571148888888888, 30.268724444444445],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23ed666e7591a6c83ef195b34337ebbd = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 14, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_21fe0eecbd50f0438c43a7ca3da69cf8);
#
#
#             var marker_29bcf5f98416ee1d2f9b921f980033aa = L.marker(
#                 [0.6888, 30.26955],
#                 {}
#             ).addTo(map_21fe0eecbd50f0438c43a7ca3da69cf8);
#
#
#             var icon_0841d4add52532601ba4ab29d3eef05e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_29bcf5f98416ee1d2f9b921f980033aa.setIcon(icon_0841d4add52532601ba4ab29d3eef05e);
#
#
#         var popup_13df1ee89d0ad33d1e2f04b0ba41c29a = L.popup({&quot;autoClose&quot;: false, &quot;closeOnClick&quot;: false, &quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f9607b7e0c7d38203d2887854c0f4a8b = $(`&lt;div id=&quot;html_f9607b7e0c7d38203d2887854c0f4a8b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kiteere,Kibimba Ward&lt;/div&gt;`)[0];
#             popup_13df1ee89d0ad33d1e2f04b0ba41c29a.setContent(html_f9607b7e0c7d38203d2887854c0f4a8b);
#
#
#         marker_29bcf5f98416ee1d2f9b921f980033aa.bindPopup(popup_13df1ee89d0ad33d1e2f04b0ba41c29a)
#         ;
#
#
#
#
#             marker_29bcf5f98416ee1d2f9b921f980033aa.bindTooltip(
#                 `&lt;div&gt;
#                      Kiteere,Kibimba Ward
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7f1e4e6cd744c3c24014094958c151ea = L.marker(
#                 [0.64726, 30.26844],
#                 {}
#             ).addTo(map_21fe0eecbd50f0438c43a7ca3da69cf8);
#
#
#             var icon_f9eacc5e215c667e281d180b36708f55 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7f1e4e6cd744c3c24014094958c151ea.setIcon(icon_f9eacc5e215c667e281d180b36708f55);
#
#
#         var popup_2bb721cc39fc79a97b4ad359684141a5 = L.popup({&quot;autoClose&quot;: false, &quot;closeOnClick&quot;: false, &quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_097b544fac2c35a5a8f7bb0e03ce5f1b = $(`&lt;div id=&quot;html_097b544fac2c35a5a8f7bb0e03ce5f1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Toro Palace, Bazaar Ward&lt;/div&gt;`)[0];
#             popup_2bb721cc39fc79a97b4ad359684141a5.setContent(html_097b544fac2c35a5a8f7bb0e03ce5f1b);
#
#
#         marker_7f1e4e6cd744c3c24014094958c151ea.bindPopup(popup_2bb721cc39fc79a97b4ad359684141a5)
#         ;
#
#
#
#
#             marker_7f1e4e6cd744c3c24014094958c151ea.bindTooltip(
#                 `&lt;div&gt;
#                      Toro Palace, Bazaar Ward
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b33960983c556c163712175482532b2b = L.marker(
#                 [0.6569, 30.27896],
#                 {}
#             ).addTo(map_21fe0eecbd50f0438c43a7ca3da69cf8);
#
#
#             var icon_3d019d46988b1211705ead93f8dd87fa = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b33960983c556c163712175482532b2b.setIcon(icon_3d019d46988b1211705ead93f8dd87fa);
#
#
#         var popup_d50515193f3424cc869914c92a2e0b3f = L.popup({&quot;autoClose&quot;: false, &quot;closeOnClick&quot;: false, &quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_54f8707cc7dfb145d23e04102b409f56 = $(`&lt;div id=&quot;html_54f8707cc7dfb145d23e04102b409f56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mpanga Market, Njara Ward&lt;/div&gt;`)[0];
#             popup_d50515193f3424cc869914c92a2e0b3f.setContent(html_54f8707cc7dfb145d23e04102b409f56);
#
#
#         marker_b33960983c556c16371
