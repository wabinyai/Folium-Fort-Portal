# %% [markdown]
# #  Mapping airqo devices in Fort Portal city  in Python using Folium

# %% [markdown]
# Engineering projects that involve data visualization occasionally include a geographic component.
#
#  Folium is a package that provides interactive Python map visualizations by running the JavaScript leaflet.js module in the background.

# %% [markdown]
# To familiarize ourselves, use the folium library to map AirQo sensors in Fort Portal City in a way that is easy for the user.

# %% [markdown]
# ## Installing folium
# Let's start by by installing folium. In Google Colab and Kaggle kernels, folium comes preinstalled.
# If you are not using the aforementioned IDE, then install using the following commands.

# %%
#pip install folium
#or 
#conda install -c conda-forge folium

# %% [markdown]
# # Library

# %% [markdown]
# Import the necessary libraries to be used in the project

# %%
import folium
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn

# %% [markdown]
# After importing the necessary libraries, read the dataset using pandas.

# %% [markdown]
# # Data frame

# %%
fort = pd.read_csv('D:\PYTHON\WORK-2022\spatial-model/fort_portal/sensor-loc-fort.csv')
#view the dataset
fort.head()
# Out:
#    Unnamed: 0      name       id   lat   long                   location
# 0           0  aq_g5_36  1429567  0.69  30.27       Kiteere,Kibimba Ward
# 1           1   aq_g533  1379966  0.65  30.27   Toro Palace, Bazaar Ward
# 2           2   aq_g530  1375499  0.66  30.28  Mpanga Market, Njara Ward
# 3           3   aq_g528  1375496  0.66  30.27        Lory Park, Rwengoma
# 4           4     aq_10   676000  0.66  30.27                   Rwengoma

# %% [markdown]
# ## Plotting Maps with Folium
#
# Plotting using folium is quite easy. The folium.Map()  class takes in latitude and longitude coordinates to generate an interactive map. You can use the + and - button on the map to zoom in and out.
#
#  The hand icon is used to drag the map to any location. Folium allows one to set a start zoom, maximum and minimum zoom number.

# %%
# Location of Fort Portal mean LONG AND LAT
map_fort=folium.Map( location=[0.66,30.27],zoom_start=13,min_zoom=8,max_zoom=14)
map_fort
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6aa0ee2fdf6b9e0753747165cc0117fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6aa0ee2fdf6b9e0753747165cc0117fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6aa0ee2fdf6b9e0753747165cc0117fb = L.map(
#                 &quot;map_6aa0ee2fdf6b9e0753747165cc0117fb&quot;,
#                 {
#                     center: [0.66, 30.27],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3ab96712cf5aa92cdc16bc7eb4abc543 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 14, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6aa0ee2fdf6b9e0753747165cc0117fb);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # To center the map

# %% [markdown]
# To easily center the map, use the mean latitude and longitude of where the devices are stationed.

# %%
long =fort['long'].mean()
lat = fort['lat'].mean()

# %%
long
# Out:
# 30.27

# %%
lat
# Out:
# 0.6588888888888889

# %%
map_fort=folium.Map( location=[lat,long],zoom_start=13,min_zoom=8,max_zoom=14)
map_fort
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9204cb1faa4b385272f48839b9a04372 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9204cb1faa4b385272f48839b9a04372&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_9204cb1faa4b385272f48839b9a04372 = L.map(
#                 &quot;map_9204cb1faa4b385272f48839b9a04372&quot;,
#                 {
#                     center: [0.6588888888888889, 30.27],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f6dba8fd69f98cc01394872e76cc64fa = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 14, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_9204cb1faa4b385272f48839b9a04372);
#
# &lt;/script&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #  Plotting Markers on the Map
#
# Markers are used to mark the locations. To add markers on the map use folium uses folium.Marker() class.
#  The latitude and longitude is picked from csv file.
# folium.Icon() class is used to create icons for the markers.

# %%
map_fort=folium.Map( location=[lat,long],zoom_start=13,min_zoom=8,max_zoom=14)

# Location of Fort Portal
 
for index, row in fort.iterrows():
    label = f'{row["location"]}'
    folium.Marker(location=[row['lat'], row['long']], 
                      popup=folium.Popup(html=label, show=False, sticky=True), 
                      icon=folium.Icon(color='red'),
                      tooltip=label).add_to(map_fort)
map_fort.save('D:\PYTHON\WORK-2022\spatial-model/fort_portal/map_fort.html')
map_fort
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c89dd883b53c7883f9c1c2fd1f3f4f0a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c89dd883b53c7883f9c1c2fd1f3f4f0a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_c89dd883b53c7883f9c1c2fd1f3f4f0a = L.map(
#                 &quot;map_c89dd883b53c7883f9c1c2fd1f3f4f0a&quot;,
#                 {
#                     center: [0.6588888888888889, 30.27],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 13,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbc085f017ca5cab9f973b2432bf8b02 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 14, &quot;maxZoom&quot;: 14, &quot;minZoom&quot;: 8, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_c89dd883b53c7883f9c1c2fd1f3f4f0a);
#
#
#             var marker_225708c9ee7aa50e0a1177fb357e3c61 = L.marker(
#                 [0.69, 30.27],
#                 {}
#             ).addTo(map_c89dd883b53c7883f9c1c2fd1f3f4f0a);
#
#
#             var icon_b59c64fe98ef2e5907f463638f8e9cac = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_225708c9ee7aa50e0a1177fb357e3c61.setIcon(icon_b59c64fe98ef2e5907f463638f8e9cac);
#
#
#         var popup_f89d2b0fff8f42ab57d3f2d3e294253d = L.popup({&quot;autoClose&quot;: false, &quot;closeOnClick&quot;: false, &quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dd4fea4a8963d61e8ac74f40000344d5 = $(`&lt;div id=&quot;html_dd4fea4a8963d61e8ac74f40000344d5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kiteere,Kibimba Ward&lt;/div&gt;`)[0];
#             popup_f89d2b0fff8f42ab57d3f2d3e294253d.setContent(html_dd4fea4a8963d61e8ac74f40000344d5);
#
#
#         marker_225708c9ee7aa50e0a1177fb357e3c61.bindPopup(popup_f89d2b0fff8f42ab57d3f2d3e294253d)
#         ;
#
#
#
#
#             marker_225708c9ee7aa50e0a1177fb357e3c61.bindTooltip(
#                 `&lt;div&gt;
#                      Kiteere,Kibimba Ward
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_b85943c76ec7cb0356dbccb0838b4ebc = L.marker(
#                 [0.65, 30.27],
#                 {}
#             ).addTo(map_c89dd883b53c7883f9c1c2fd1f3f4f0a);
#
#
#             var icon_a2e10374a905a40dc8f41281303937f6 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_b85943c76ec7cb0356dbccb0838b4ebc.setIcon(icon_a2e10374a905a40dc8f41281303937f6);
#
#
#         var popup_89665eaa4ec02bfe5781a4df4a097652 = L.popup({&quot;autoClose&quot;: false, &quot;closeOnClick&quot;: false, &quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_5984860841bb4f89219b242b79853b16 = $(`&lt;div id=&quot;html_5984860841bb4f89219b242b79853b16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Toro Palace, Bazaar Ward&lt;/div&gt;`)[0];
#             popup_89665eaa4ec02bfe5781a4df4a097652.setContent(html_5984860841bb4f89219b242b79853b16);
#
#
#         marker_b85943c76ec7cb0356dbccb0838b4ebc.bindPopup(popup_89665eaa4ec02bfe5781a4df4a097652)
#         ;
#
#
#
#
#             marker_b85943c76ec7cb0356dbccb0838b4ebc.bindTooltip(
#                 `&lt;div&gt;
#                      Toro Palace, Bazaar Ward
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_6fe6b0328186b96d5483687f7cba9fe0 = L.marker(
#                 [0.66, 30.28],
#                 {}
#             ).addTo(map_c89dd883b53c7883f9c1c2fd1f3f4f0a);
#
#
#             var icon_b19c53541705a50a7d15d7cc09f8893e = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_6fe6b0328186b96d5483687f7cba9fe0.setIcon(icon_b19c53541705a50a7d15d7cc09f8893e);
#
#
#         var popup_5c509cade2b7bdfb6c1f54ea0b4b7a4a = L.popup({&quot;autoClose&quot;: false, &quot;closeOnClick&quot;: false, &quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_bf75b002b2ae8dce62ef9c53fa1da918 = $(`&lt;div id=&quot;html_bf75b002b2ae8dce62ef9c53fa1da918&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mpanga Market, Njara Ward&lt;/div&gt;`)[0];
#             popup_5c509cade2b7bdfb6c1f54ea0b4b7a4a.setContent(html_bf75b002b2ae8dce62ef9c53fa1da918);
#
#
#         marker_6fe6b0328186b96d5483687f7cba9fe0.bindPopup(popup
